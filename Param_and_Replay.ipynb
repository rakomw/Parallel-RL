# %%
# !pip install ray
# Out:
# Requirement already satisfied: ray in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.7/dist-packages (from ray) (0.7.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from ray) (3.12.4)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ray) (0.3.5)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.7/dist-packages (from ray) (0.7.12)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray) (1.32.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray) (2.6.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.7/dist-packages (from ray) (0.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray) (3.13)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.0.2)
# Requirement already satisfied: aioredis in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: gpustat in /usr/local/lib/python3.7/dist-packages (from ray) (0.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from ray) (3.7.4.post0)
# Requirement already satisfied: redis>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ray) (3.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray) (3.0.12)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from ray) (0.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray) (1.19.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->ray) (54.2.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->ray) (1.15.0)
# Requirement already satisfied: opencensus-context==0.1.2 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray) (0.1.2)
# Requirement already satisfied: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray) (1.26.2)
# Requirement already satisfied: async-timeout in /usr/local/lib/python3.7/dist-packages (from aioredis->ray) (3.0.1)
# Requirement already satisfied: hiredis in /usr/local/lib/python3.7/dist-packages (from aioredis->ray) (2.0.0)
# Requirement already satisfied: blessings>=1.6 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (1.7)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (5.4.8)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (3.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (3.7.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (20.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2020.12.5)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.53.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.28.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (20.9)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2018.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.7.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.4.8)

# %%
import gym
import random
import os
import numpy as np
import tensorflow as tf
import ray
import time

from collections      import deque
from keras import models
from keras import optimizers
from keras import layers

# %%
@ray.remote
class ParameterServer(object):
    def __init__(self,state_size,action_size):
      self.opt = optimizers.Adam(lr=0.001)
      self.state_size = state_size 
      self.action_size = action_size
      #self.model = self.build_model()
      self.model = models.load_model("model.h5")

    def get_weights(self):
      return self.model.get_weights()
    
    def build_model(self):
        model = models.Sequential()
        model.add(layers.Input(shape=self.state_size))
        model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2))
        model.add(layers.Conv2D(32, 8, strides=4, activation="relu"))
        model.add(layers.Conv2D(64,4,strides=2,activation="relu"))
        model.add(layers.Conv2D(64, 3, strides=1, activation="relu"))
        model.add(layers.Flatten())
        model.add(layers.Dense(512, activation="relu"))
        model.add(layers.Dense(self.action_size, activation="linear"))
        model.compile(loss='mse', optimizer=self.opt)
        return model
    
    def apply_gradient(self,grad):
      var_list = self.model.trainable_variables
      self.opt.apply_gradients(zip(grad, var_list))
    
    def save_weights(self, version):
      self.model.save("savedModels/model{}.h5".format(version))

# %%
#handle adding to and sampling from a shared replay memory
#only one of these should be created
@ray.remote
class ReplayMemory(object):
    def __init__(self,state_size,action_size):
        #deque is an efficient collection for the necessary operations
        self.replays = deque(maxlen=100000)
        self.state_size = state_size
        self.action_size = action_size
        
    def addMemory(self, state, action, reward, new_state, done):
        self.replays.append([state, action, reward, new_state, done])

    def sampleReplays(self,batch_size):
        #return whatever replays are there if there aren't enough for a full batch
        #in practice this shouldn't ever happen
        if(len(self.replays) < batch_size):
            return np.array(self.replays)
        #return a randomly sampled batch from the replay memory
        return np.array(random.sample(self.replays, batch_size))

# %%
@ray.remote(num_gpus=1)
class Learner(object):
    def __init__(self,param_server,replay_memory,state_size,action_size,batch_size=32,gamma=0.95):
        self.param_server = param_server
        self.replay_memory = replay_memory
        self.state_size = state_size
        self.action_size = action_size 
        self.sample_batch_size = batch_size
        self.gamma = gamma
        self.opt = optimizers.Adam(lr=0.001)
        #initialize a local copy of Q network
        self.Q_network = self.build_model()
        #get the weights from parameter server and copy them into local network
        self.Q_network.set_weights(ray.get(self.param_server.get_weights.remote()))
        #initialize target network from Q network
        self.target_network = models.clone_model(self.Q_network)
        self.target_network.set_weights(self.Q_network.get_weights())

    def build_model(self):
        model = models.Sequential()
        model.add(layers.Input(shape=self.state_size))
        model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2))
        model.add(layers.Conv2D(32, 8, strides=4, activation="relu"))
        model.add(layers.Conv2D(64,4,strides=2,activation="relu"))
        model.add(layers.Conv2D(64, 3, strides=1, activation="relu"))
        model.add(layers.Flatten())
        model.add(layers.Dense(512, activation="relu"))
        model.add(layers.Dense(self.action_size, activation="linear"))
        model.compile(loss='mse', optimizer=self.opt)
        return model

    def learn(self, step,num_batches=1):
      for _ in range(num_batches):
        #retrieve a batch of replays from the shared memory 
        mini_batch = ray.get(self.replay_memory.sampleReplays.remote(self.sample_batch_size))
        #on the first iteration we'll need to wait until some replays are generated
        if (len(mini_batch) < self.sample_batch_size):
          return 
        states = np.zeros((self.sample_batch_size,) + self.state_size)
        #print(states.shape)
        next_states = np.zeros((self.sample_batch_size,) + self.state_size)
        actions, rewards, dones = [], [], []
        for i in range(self.sample_batch_size):
                states[i] = mini_batch[i][0]
                actions.append(mini_batch[i][1])
                rewards.append(mini_batch[i][2])
                next_states[i] = mini_batch[i][3]
                dones.append(mini_batch[i][4])
        target =  self.Q_network.predict(states)
        target_val = self.target_network.predict(next_states)
        for i in range(self.sample_batch_size):
                if dones[i]:
                    target[i][actions[i]] = rewards[i]
                else:
                    target[i][actions[i]] = rewards[i] + 0.99 * (
                        np.amax(target_val[i]))
        
        dqn_variable = self.Q_network.trainable_variables
        with tf.GradientTape() as tape:  
            tape.watch(dqn_variable)
            rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
            actions = tf.convert_to_tensor(actions, dtype=tf.int32)
            dones = tf.convert_to_tensor(dones, dtype=tf.float32)

            target_q = self.target_network(tf.convert_to_tensor(next_states, dtype=tf.float32))
            next_action = tf.argmax(target_q, axis=1)
            target_value = tf.reduce_sum(tf.one_hot(next_action, self.action_size) * target_q, axis=1)
            target_value = (1-dones) * self.gamma * target_value + rewards

            main_q = self.Q_network(tf.convert_to_tensor(states, dtype=tf.float32))
            main_value = tf.reduce_sum(tf.one_hot(actions, self.action_size) * main_q, axis=1)

            loss = tf.math.reduce_mean(tf.square(main_value - target_value))
        grad = tape.gradient(loss, dqn_variable)
        ray.get(self.param_server.apply_gradient.remote(grad))
        #sync weights from parameter server 
        self.Q_network.set_weights(ray.get(self.param_server.get_weights.remote()))
        #sync target network periodically 
        if (step % 10000) == 0:
          self.target_network.set_weights(self.Q_network.get_weights())
          print("Synced Target Network")
        #print("Learning {}".format(step))

# %%
@ray.remote 
class Actor(object):
    def __init__(self,param_server,replay_memory,environment):
        self.param_server = param_server 
        self.replay_memory = replay_memory
        self.env = environment 
        self.done = True
        self.total_reward = 0
        self.episodes = 0
        self.state_size = self.env.observation_space.shape
        self.action_size = self.env.action_space.n 
        self.exploration_rate = 1.0
        self.exploration_min = 0.01
        self.exploration_decay = 0.995
        #make a local copy of the Q-network
        self.Q_network = self.build_model()
        self.Q_network.set_weights(ray.get(self.param_server.get_weights.remote()))

    def build_model(self):
        model = models.Sequential()
        model.add(layers.Input(shape=self.state_size))
        model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2))
        model.add(layers.Conv2D(32, 8, strides=4, activation="relu"))
        model.add(layers.Conv2D(64,4,strides=2,activation="relu"))
        model.add(layers.Conv2D(64, 3, strides=1, activation="relu"))
        model.add(layers.Flatten())
        model.add(layers.Dense(512, activation="relu"))
        model.add(layers.Dense(self.action_size, activation="linear"))
        model.compile()
        return model
  
    def sync_network(self):
        self.Q_network.set_weights(ray.get(self.param_server.get_weights.remote()))
  
    def run_episode(self):
        state = self.env.reset()
        state = np.expand_dims(state, 0)
        total_reward = 0
        done = False 
        while not done:
          if np.random.rand() <= self.exploration_rate:
            action = random.randrange(self.action_size)
          else:
            expected_values = self.Q_network.predict(state)
            action = np.argmax(expected_values[0])

          next_state, reward, done, _ = self.env.step(action)
          next_state = np.expand_dims(next_state, 0)
          total_reward += reward 
          ray.get(self.replay_memory.addMemory.remote(state,action,reward,next_state,done))
          state = next_state 
          if self.exploration_rate > self.exploration_min:
            self.exploration_rate *= self.exploration_decay

        #print("Score: {}".format(total_reward))
        return total_reward 
    def run_step(self):
      if self.done:
        self.episodes += 1
        self.env.close()
        self.state = self.env.reset()
        self.done = False 

      state = np.expand_dims(self.state, 0)
      if np.random.rand() <= self.exploration_rate:
        action = random.randrange(self.action_size)
      else:
        expected_values = self.Q_network.predict(state)
        action = np.argmax(expected_values[0])

      next_state, reward, self.done, _ = self.env.step(action)
      #next_state = np.expand_dims(next_state, 0)
      self.total_reward += reward 
      ray.get(self.replay_memory.addMemory.remote(state,action,reward,next_state,self.done))
      self.state = next_state 

      if self.exploration_rate > self.exploration_min:
        self.exploration_rate *= self.exploration_decay
    
    def get_average(self):
      if self.episodes == 0:
        return 0
      return (self.total_reward / self.episodes)

# %%
class Agent(object):
    def __init__(self,env_name,num_actors,num_learners):
        self.env = gym.make(env_name)
        self.state_size = self.env.observation_space.shape
        self.action_size = self.env.action_space.n 
        self.parameter_server = ParameterServer.remote(self.state_size, self.action_size)
        self.replay_memory = ReplayMemory.remote(self.state_size, self.action_size)
        self.actors = [Actor.remote(self.parameter_server, self.replay_memory, gym.make(env_name)) for _ in range(num_actors)]
        self.learners = [Learner.remote(self.parameter_server, self.replay_memory, self.state_size, self.action_size) for _ in range(num_learners)]

    def run(self):
        counter = 0
        max_score = 0
        while counter < 1000000:
          if (counter % 100 == 0):
            print("Global step {}".format(counter))
            print("Average score {}".format(np.average(ray.get([actor.get_average.remote() for actor in self.actors]))))
          ray.get([actor.sync_network.remote() for actor in self.actors])
          ray.get([actor.run_step.remote() for actor in self.actors])
          ray.get([learner.learn.remote(counter) for learner in self.learners])
          #avg_score = np.average(scores)
          #print("Average reward {}".format(avg_score))
          #if avg_score > max_score:
            #max_score = avg_score
          if (counter % 5000) == 0:
            self.save_weights(":.0f".format(counter / 5000))
          counter += 1

    def save_weights(self, suffix):
      ray.get(self.parameter_server.save_weights.remote(suffix))

# %%
ray.shutdown()
ray.init(ignore_reinit_error=True)
# Out:
# 2021-04-11 14:10:34,176	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# {'metrics_export_port': 43242,
#  'node_id': '33ca2dcca3f44ab652734ab298b5413a8764ab3b905f00289dcaba55',
#  'node_ip_address': '172.28.0.2',
#  'object_store_address': '/tmp/ray/session_2021-04-11_14-10-33_762780_75/sockets/plasma_store',
#  'raylet_ip_address': '172.28.0.2',
#  'raylet_socket_name': '/tmp/ray/session_2021-04-11_14-10-33_762780_75/sockets/raylet',
#  'redis_address': '172.28.0.2:6379',
#  'session_dir': '/tmp/ray/session_2021-04-11_14-10-33_762780_75',
#  'webui_url': '127.0.0.1:8265'}

# %%
agent = Agent("Breakout-v0",4,1)
agent.run()
# Out:
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204145) 2021-04-11 14:10:37.315053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204143) 2021-04-11 14:10:37.550583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204144) 2021-04-11 14:10:37.924855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Global step 0
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.375908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.377022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204145) 2021-04-11 14:10:39.386768: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=1204145) 2021-04-11 14:10:39.386870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.386931: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: f56d8ca326d5
# (pid=1204145) 2021-04-11 14:10:39.387086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.387151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# (pid=1204145) 2021-04-11 14:10:39.390098: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# (pid=1204219) 2021-04-11 14:10:39.385005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
# Global step 8900
# Average score 1.5040535927632703
# Global step 9000
# Average score 1.4749960089399745
# Global step 9100
# Average score 1.510117337164751
# Global step 9200
# Average score 1.5001741553465693
# Global step 9300
# Average score 1.5087948450017417
# Global step 9400
# Average score 1.4677521008403362
# Global step 9500
# Average score 1.4677521008403362
# Global step 9600
# Average score 1.4629709948495528
# Global step 9700
# Average score 1.438133874239351
# Global step 9800
# Average score 1.452582234228508
# Global step 9900
# Average score 1.4655736036071827
# Global step 10000
# Average score 1.4655736036071827
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# Global step 10100
# Average score 1.4542410714285714
# Global step 10200
# Average score 1.4418402777777777
# Global step 10300
# Average score 1.4577493686868686
# Global step 10400
# Average score 1.4655618686868686
# Global step 10500
# Average score 1.4733743686868686
# Global step 10600
# Average score 1.4454566046122024
# Global step 10700
# Average score 1.4522060715009881
# Global step 10800
# Average score 1.4300644875946982
# Global step 10900
# Average score 1.4324635117204776
# Global step 11000
# Average score 1.452764263600177
# Global step 11100
# Average score 1.4334254196096299
# Global step 11200
# Average score 1.4532328782328785
# Global step 11300
# Average score 1.4603757353757356
# Global step 11400
# Average score 1.450991350991351
# Global step 11500
# Average score 1.4524520149520148
# Global step 11600
# Average score 1.4544150768415476
# Global step 11700
# Average score 1.4544150768415476
# Global step 11800
# Average score 1.4468219824445754
# Global step 11900
# Average score 1.4734933906949312
# Global step 12000
# Average score 1.4695358617374021
# Global step 12100
# Average score 1.4687106279211541
# Global step 12200
# Average score 1.4829963422068686
# Global step 12300
# Average score 1.4841478696741854
# Global step 12400
# Average score 1.463397331282888
# Global step 12500
# Average score 1.463397331282888
# Global step 12600
# Average score 1.4682804114490162
# Global step 12700
# Average score 1.493699065792089
# Global step 12800
# Average score 1.5123335321009739
# Global step 12900
# Average score 1.5053469382737676
# Global step 13000
# Average score 1.5246115124163904
# Global step 13100
# Average score 1.5246115124163904
# Global step 13200
# Average score 1.5041934791934792
# Global step 13300
# Average score 1.506015037593985
# Global step 13400
# Average score 1.4972137592464478
# Global step 13500
# Average score 1.5053411661784117
# Global step 13600
# Average score 1.4872550346436877
# Global step 13700
# Average score 1.4977624434033359
# Global step 13800
# Average score 1.5099575653545554
# Global step 13900
# Average score 1.5005722114764666
# Global step 14000
# Average score 1.5065245924288475
# Global step 14100
# Average score 1.488151492660399
# Global step 14200
# Average score 1.489565607865381
# Global step 14300
# Average score 1.5125246187054895
# Global step 14400
# Average score 1.4998994150827205
# Global step 14500
# Average score 1.5165337994833525
# Global step 14600
# Average score 1.5229869572431305
# Global step 14700
# Average score 1.5112401698267959
# Global step 14800
# Average score 1.511440024668517
# Global step 14900
# Average score 1.516759173604687
# Global step 15000
# Average score 1.522711554557068
# Global step 15100
# Average score 1.4973755954633214
# Global step 15200
# Average score 1.495074542063238
# Global step 15300
# Average score 1.4946667760945966
# Global step 15400
# Average score 1.4964306526806526
# Global step 15500
# Average score 1.517737470862471
# Global step 15600
# Average score 1.5304353384710527
# Global step 15700
# Average score 1.5231597767312053
# Global step 15800
# Average score 1.5287153322867608
# Global step 15900
# Average score 1.517949138638228
# Global step 16000
# Average score 1.517949138638228
# Global step 16100
# Average score 1.527949138638228
# Global step 16200
# Average score 1.5256072962408918
# Global step 16300
# Average score 1.5022945348352108
# Global step 16400
# Average score 1.4955072045184687
# Global step 16500
# Average score 1.5103579438685821
# Global step 16600
# Average score 1.5023451233557616
# Global step 16700
# Average score 1.4962003422109804
# Global step 16800
# Average score 1.495206464133351
# Global step 16900
# Average score 1.502367424242424
# Global step 17000
# Average score 1.503232751076417
# Global step 17100
# Average score 1.5053680172278554
# Global step 17200
# Average score 1.5017479213907785
# Global step 17300
# Average score 1.5034374355802926
# Global step 17400
# Average score 1.5094492544492546
# Global step 17500
# Average score 1.5075162337662338
# Global step 17600
# Average score 1.5169805194805195
# Global step 17700
# Average score 1.5045482188090546
# Global step 17800
# Average score 1.518897594923137
# Global step 17900
# Average score 1.5217876570690971
# Global step 18000
# Average score 1.5083990719699856
# Global step 18100
# Average score 1.5091768296736534
# Global step 18200
# Average score 1.494500536734995
# Global step 18300
# Average score 1.5035455171782806
# Global step 18400
# Average score 1.5035455171782806
# Global step 18500
# Average score 1.502415296315621
# Global step 18600
# Average score 1.490131005811453
# Global step 18700
# Average score 1.4868727947702234
# Global step 18800
# Average score 1.487413684871312
# Global step 18900
# Average score 1.4944340248834551
# Global step 19000
# Average score 1.4990636545130849
# Global step 19100
# Average score 1.5003000623068699
# Global step 19200
# Average score 1.4881520119225038
# Global step 19300
# Average score 1.4926974664679584
# Global step 19400
# Average score 1.4910581222056634
# Global step 19500
# Average score 1.4791596557857796
# Global step 19600
# Average score 1.4884816234796405
# Global step 19700
# Average score 1.4884816234796405
# Global step 19800
# Average score 1.4868196154717839
# Global step 19900
# Average score 1.4725051877004338
# Global step 20000
# Average score 1.480505699733204
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# Global step 20100
# Average score 1.4832175575026276
# Global step 20200
# Average score 1.4757890820802004
# Global step 20300
# Average score 1.4750808189655173
# Global step 20400
# Average score 1.485056780503979
# Global step 20500
# Average score 1.493273375331565
# Global step 20600
# Average score 1.493273375331565
# Global step 20700
# Average score 1.4920550847457628
# Global step 20800
# Average score 1.4892556595946427
# Global step 20900
# Average score 1.500735846074829
# Global step 21000
# Average score 1.501602564102564
# Global step 21100
# Average score 1.5030568312284731
# Global step 21200
# Average score 1.500785843509724
# Global step 21300
# Average score 1.513043018884712
# Global step 21400
# Average score 1.5195724062252078
# Global step 21500
# Average score 1.521859967934501
# Global step 21600
# Average score 1.527428251701953
# Global step 21700
# Average score 1.5245493358633775
# Global step 21800
# Average score 1.5323129372114759
# Global step 21900
# Average score 1.5198794103896818
# Global step 22000
# Average score 1.5275881390424333
# Global step 22100
# Average score 1.5286404416839199
# Global step 22200
# Average score 1.5212829334632403
# Global step 22300
# Average score 1.5212829334632403
# Global step 22400
# Average score 1.5319196428571429
# Global step 22500
# Average score 1.5391142598343686
# Global step 22600
# Average score 1.5414123099101857
# Global step 22700
# Average score 1.5329633879082745
# Global step 22800
# Average score 1.527735644637053
# Global step 22900
# Average score 1.5297924297924297
# Global step 23000
# Average score 1.5407814407814406
# Global step 23100
# Average score 1.5271953691848057
# Global step 23200
# Average score 1.5222010769473628
# Global step 23300
# Average score 1.5329347400300517
# Global step 23400
# Average score 1.5373432411284524
# Global step 23500
# Average score 1.5289725359688044
# Global step 23600
# Average score 1.5311830947692737
# Global step 23700
# Average score 1.527216850210404
# Global step 23800
# Average score 1.530893320798639
# Global step 23900
# Average score 1.5362654566331038
# Global step 24000
# Average score 1.5376150626855702
# Global step 24100
# Average score 1.5267696146665457
# Global step 24200
# Average score 1.5255546325611529
# Global step 24300
# Average score 1.5356020971129432
# Global step 24400
# Average score 1.5262296712296712
# Global step 24500
# Average score 1.5285291699765384
# Global step 24600
# Average score 1.5386368254789307
# Global step 24700
# Average score 1.529314401931155
# Global step 24800
# Average score 1.5359372089486991
# Global step 24900
# Average score 1.5378180035926514
# Global step 25000
# Average score 1.5275199554313479
# Global step 25100
# Average score 1.5242632048719658
# Global step 25200
# Average score 1.5232259334233018
# Global step 25300
# Average score 1.5312447968697969
# Global step 25400
# Average score 1.527664426348751
# Global step 25500
# Average score 1.5340361795955042
# Global step 25600
# Average score 1.5251299376299374
# Global step 25700
# Average score 1.5205774684941353
# Global step 25800
# Average score 1.5088576340053135
# Global step 25900
# Average score 1.50437856143681
# Global step 26000
# Average score 1.5074649811898961
# Global step 26100
# Average score 1.4960446084724006
# Global step 26200
# Average score 1.5052671694480102
# Global step 26300
# Average score 1.5210686777920412
# Global step 26400
# Average score 1.5198768114821286
# Global step 26500
# Average score 1.5149385398771904
# Global step 26600
# Average score 1.5146009724322977
# Global step 26700
# Average score 1.5194254652085977
# Global step 26800
# Average score 1.5153918407481441
# Global step 26900
# Average score 1.5112682033413742
# Global step 27000
# Average score 1.5126743236682996
# Global step 27100
# Average score 1.5173850541143241
# Global step 27200
# Average score 1.5171361544465278
# Global step 27300
# Average score 1.5153441123284757
# Global step 27400
# Average score 1.5132615546218486
# Global step 27500
# Average score 1.5117909663865545
# Global step 27600
# Average score 1.519670542635659
# Global step 27700
# Average score 1.523986833105335
# Global step 27800
# Average score 1.5175397861184927
# Global step 27900
# Average score 1.5158639995247853
# Global step 28000
# Average score 1.517601502866138
# Global step 28100
# Average score 1.511342669561419
# Global step 28200
# Average score 1.5172650132676149
# Global step 28300
# Average score 1.5214840265565666
# Global step 28400
# Average score 1.511283797972348
# Global step 28500
# Average score 1.514124707063257
# Global step 28600
# Average score 1.5181099782172613
# Global step 28700
# Average score 1.5162216061092464
# Global step 28800
# Average score 1.520658531543363
# Global step 28900
# Average score 1.520572498662386
# Global step 29000
# Average score 1.5187596386869355
# Global step 29100
# Average score 1.5144837335683337
# Global step 29200
# Average score 1.5160130718954248
# Global step 29300
# Average score 1.5145173453996983
# Global step 29400
# Average score 1.521712274653451
# Global step 29500
# Average score 1.5199072890933356
# Global step 29600
# Average score 1.5270358096571444
# Global step 29700
# Average score 1.521573156368404
# Global step 29800
# Average score 1.5156263923160715
# Global step 29900
# Average score 1.5170902451999806
# Global step 30000
# Average score 1.5044685123744985
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# (pid=1204219) Synced Target Network
# Global step 30100
# Average score 1.5044685123744985
# Global step 30200
# Average score 1.5005823506166678
# Global step 30300
# Average score 1.4882335641568583
# Global step 30400
# Average score 1.4882335641568583
# Global step 30500
# Average score 1.4839888700245236
# Global step 30600
# Average score 1.4802962081622497
# Global step 30700
# Average score 1.4788043784789306
# Global step 30800
# Average score 1.48415579789285
# Global step 30900
# Average score 1.4946552846416368
# Global step 31000
# Average score 1.4933662280701754
# Global step 31100
# Average score 1.4894465545306566
# Global step 31200
# Average score 1.4882979664535612
# Global step 31300
# Average score 1.484515071716719
# Global step 31400
# Average score 1.4818531066400622
# Global step 31500
# Average score 1.4844041270482253
# Global step 31600
# Average score 1.4847023611572998
# Global step 31700
# Average score 1.4884580175566606
# Global step 31800
# Average score 1.4835140374654052
# Global step 31900
# Average score 1.4874620060790273
# Global step 32000
# Average score 1.4885091516670463
# Global step 32100
# Average score 1.4914021796916535
# Global step 32200
# Average score 1.5015590111642743
# Global step 32300
# Average score 1.5027711323763955
# Global step 32400
# Average score 1.497482310731073
# Global step 32500
# Average score 1.4963964521452144
# Global step 32600
# Average score 1.5014758663366337
# Global step 32700
# Average score 1.510292904290429
# Global step 32800
# Average score 1.5014200025217805
# Global step 32900
# Average score 1.5038952500465328
# Global step 33000
# Average score 1.5054290829325505
# Global step 33100
# Average score 1.497749099639856
# Global step 33200
# Average score 1.5027511004401761
# Global step 33300
# Average score 1.5054211004790266
# Global step 33400
# Average score 1.5054211004790266
# Global step 33500
# Average score 1.4978179856820635
# Global step 33600
# Average score 1.499106307662133
# Global step 33700
# Average score 1.5031065886648411
# Global step 33800
# Average score 1.5042735042735043
# Global step 33900
# Average score 1.4992673992673993
# Global step 34000
# Average score 1.5041712454212455
# Global step 34100
# Average score 1.5053846153846155
# Global step 34200
# Average score 1.5067394947819477
# Global step 34300
# Average score 1.5052572023219324
# Global step 34400
# Average score 1.5007241778917546
# Global step 34500
# Average score 1.5031994254165069
# Global step 34600
# Average score 1.5011559062465096
# Global step 34700
# Average score 1.4972731650312117
# Global step 34800
# Average score 1.4951082215818645
# Global step 34900
# Average score 1.498750681560328
# Global step 35000
# Average score 1.5083475815088103

# %%
agent.save_weights()
